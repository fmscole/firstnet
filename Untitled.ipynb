# %%
from pyecharts import Bar

bar = Bar("我的第一个图表", "这里是副标题")
bar.add("服装", ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"], [5, 20, 36, 10, 75, 90])
# bar.print_echarts_options() # 该行只为了打印配置项，方便调试时使用
bar.render()    # 生成本地 HTML 文件

# %%
from pyecharts import Geo

data = [
    ("海门", 9),("鄂尔多斯", 12),("招远", 12),("舟山", 12),("齐齐哈尔", 14),("盐城", 15),
    ("赤峰", 16),("青岛", 18),("乳山", 18),("金昌", 19),("泉州", 21),("莱西", 21),
    ("日照", 21),("胶南", 22),("南通", 23),("拉萨", 24),("云浮", 24),("梅州", 25),
    ("文登", 25),("上海", 25),("攀枝花", 25),("威海", 25),("承德", 25),("厦门", 26),
    ("汕尾", 26),("潮州", 26),("丹东", 27),("太仓", 27),("曲靖", 27),("烟台", 28),
    ("福州", 29),("瓦房店", 30),("即墨", 30),("抚顺", 31),("玉溪", 31),("张家口", 31),
    ("阳泉", 31),("莱州", 32),("湖州", 32),("汕头", 32),("昆山", 33),("宁波", 33),
    ("湛江", 33),("揭阳", 34),("荣成", 34),("连云港", 35),("葫芦岛", 35),("常熟", 36),
    ("东莞", 36),("河源", 36),("淮安", 36),("泰州", 36),("南宁", 37),("营口", 37),
    ("惠州", 37),("江阴", 37),("蓬莱", 37),("韶关", 38),("嘉峪关", 38),("广州", 38),
    ("延安", 38),("太原", 39),("清远", 39),("中山", 39),("昆明", 39),("寿光", 40),
    ("盘锦", 40),("长治", 41),("深圳", 41),("珠海", 42),("宿迁", 43),("咸阳", 43),
    ("铜川", 44),("平度", 44),("佛山", 44),("海口", 44),("江门", 45),("章丘", 45),
    ("肇庆", 46),("大连", 47),("临汾", 47),("吴江", 47),("石嘴山", 49),("沈阳", 50),
    ("苏州", 50),("茂名", 50),("嘉兴", 51),("长春", 51),("胶州", 52),("银川", 52),
    ("张家港", 52),("三门峡", 53),("锦州", 54),("南昌", 54),("柳州", 54),("三亚", 54),
    ("自贡", 56),("吉林", 56),("阳江", 57),("泸州", 57),("西宁", 57),("宜宾", 58),
    ("呼和浩特", 58),("成都", 58),("大同", 58),("镇江", 59),("桂林", 59),("张家界", 59),
    ("宜兴", 59),("北海", 60),("西安", 61),("金坛", 62),("东营", 62),("牡丹江", 63),
    ("遵义", 63),("绍兴", 63),("扬州", 64),("常州", 64),("潍坊", 65),("重庆", 66),
    ("台州", 67),("南京", 67),("滨州", 70),("贵阳", 71),("无锡", 71),("本溪", 71),
    ("克拉玛依", 72),("渭南", 72),("马鞍山", 72),("宝鸡", 72),("焦作", 75),("句容", 75),
    ("北京", 79),("徐州", 79),("衡水", 80),("包头", 80),("绵阳", 80),("乌鲁木齐", 84),
    ("枣庄", 84),("杭州", 84),("淄博", 85),("鞍山", 86),("溧阳", 86),("库尔勒", 86),
    ("安阳", 90),("开封", 90),("济南", 92),("德阳", 93),("温州", 95),("九江", 96),
    ("邯郸", 98),("临安", 99),("兰州", 99),("沧州", 100),("临沂", 103),("南充", 104),
    ("天津", 105),("富阳", 106),("泰安", 112),("诸暨", 112),("郑州", 113),("哈尔滨", 114),
    ("聊城", 116),("芜湖", 117),("唐山", 119),("平顶山", 119),("邢台", 119),("德州", 120),
    ("济宁", 120),("荆州", 127),("宜昌", 130),("义乌", 132),("丽水", 133),("洛阳", 134),
    ("秦皇岛", 136),("株洲", 143),("石家庄", 147),("莱芜", 148),("常德", 152),("保定", 153),
    ("湘潭", 154),("金华", 157),("岳阳", 169),("长沙", 175),("衢州", 177),("廊坊", 193),
    ("菏泽", 194),("合肥", 229),("武汉", 273),("大庆", 279)]
geo = Geo("全国主要城市空气质量", "data from pm2.5", title_color="#fff",
          title_pos="center", width=1000,
          height=600, background_color='#404a59')
attr, value = geo.cast(data)
geo.add("", attr, value, visual_range=[0, 200], maptype='china',visual_text_color="#fff",
        symbol_size=10, is_visualmap=True)
geo.render("全国主要城市空气质量.html")#生成html文件
geo#直接在notebook中显示
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'china': '/nbextensions/echarts-countries-js/china'
#         }
#     });
# </script>
#     <div id="3631356ba35a43068cb3f9a068070049" style="width:1000px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#
# var myChart_3631356ba35a43068cb3f9a068070049 = echarts.init(document.getElementById('3631356ba35a43068cb3f9a068070049'), 'light', {renderer: 'canvas'});
#
# var option_3631356ba35a43068cb3f9a068070049 = {
#     "toolbox": {
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         },
#         "orient": "vertical",
#         "left": "95%",
#         "show": true,
#         "top": "center"
#     },
#     "series_id": 789094,
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "show": true,
#             "top": "top",
#             "left": "center",
#             "orient": "horizontal",
#             "selectedMode": "multiple"
#         }
#     ],
#     "geo": {
#         "itemStyle": {
#             "emphasis": {
#                 "areaColor": "#2a333d"
#             },
#             "normal": {
#                 "areaColor": "#323c48",
#                 "borderColor": "#111"
#             }
#         },
#         "label": {
#             "emphasis": {
#                 "textStyle": {
#                     "color": "#eee"
#                 },
#                 "show": true
#             }
#         },
#         "roam": true,
#         "map": "china"
#     },
#     "visualMap": {
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "showLabel": true,
#         "type": "continuous",
#         "max": 200,
#         "calculable": true,
#         "left": "left",
#         "min": 0,
#         "splitNumber": 5,
#         "textStyle": {
#             "color": "#fff"
#         },
#         "top": "bottom",
#         "text": [
#             "high",
#             "low"
#         ],
#         "orient": "vertical"
#     },
#     "tooltip": {
#         "triggerOn": "mousemove|click",
#         "trigger": "item",
#         "borderColor": "#333",
#         "borderWidth": 0,
#         "formatter": "{b}: {c}",
#         "axisPointer": {
#             "type": "line"
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "textStyle": {
#             "fontSize": 14
#         }
#     },
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "backgroundColor": "#404a59",
#     "title": [
#         {
#             "textStyle": {
#                 "color": "#fff",
#                 "fontSize": 18
#             },
#             "subtext": "data from pm2.5",
#             "top": "auto",
#             "text": "\u5168\u56fd\u4e3b\u8981\u57ce\u5e02\u7a7a\u6c14\u8d28\u91cf",
#             "left": "center",
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "series": [
#         {
#             "symbolSize": 10,
#             "data": [
#                 {
#                     "value": [
#                         121.15,
#                         31.89,
#                         9
#                     ],
#                     "name": "\u6d77\u95e8"
#                 },
#                 {
#                     "value": [
#                         109.781327,
#                         39.608266,
#                         12
#                     ],
#                     "name": "\u9102\u5c14\u591a\u65af"
#                 },
#                 {
#                     "value": [
#                         120.38,
#                         37.35,
#                         12
#                     ],
#                     "name": "\u62db\u8fdc"
#                 },
#                 {
#                     "value": [
#                         122.207216,
#                         29.985295,
#                         12
#                     ],
#                     "name": "\u821f\u5c71"
#                 },
#                 {
#                     "value": [
#                         123.97,
#                         47.33,
#                         14
#                     ],
#                     "name": "\u9f50\u9f50\u54c8\u5c14"
#                 },
#                 {
#                     "value": [
#                         120.13,
#                         33.38,
#                         15
#                     ],
#                     "name": "\u76d0\u57ce"
#                 },
#                 {
#                     "value": [
#                         118.87,
#                         42.28,
#                         16
#                     ],
#                     "name": "\u8d64\u5cf0"
#                 },
#                 {
#                     "value": [
#                         120.33,
#                         36.07,
#                         18
#                     ],
#                     "name": "\u9752\u5c9b"
#                 },
#                 {
#                     "value": [
#                         121.52,
#                         36.89,
#                         18
#                     ],
#                     "name": "\u4e73\u5c71"
#                 },
#                 {
#                     "value": [
#                         102.188043,
#                         38.520089,
#                         19
#                     ],
#                     "name": "\u91d1\u660c"
#                 },
#                 {
#                     "value": [
#                         118.58,
#                         24.93,
#                         21
#                     ],
#                     "name": "\u6cc9\u5dde"
#                 },
#                 {
#                     "value": [
#                         120.53,
#                         36.86,
#                         21
#                     ],
#                     "name": "\u83b1\u897f"
#                 },
#                 {
#                     "value": [
#                         119.46,
#                         35.42,
#                         21
#                     ],
#                     "name": "\u65e5\u7167"
#                 },
#                 {
#                     "value": [
#                         119.97,
#                         35.88,
#                         22
#                     ],
#                     "name": "\u80f6\u5357"
#                 },
#                 {
#                     "value": [
#                         121.05,
#                         32.08,
#                         23
#                     ],
#                     "name": "\u5357\u901a"
#                 },
#                 {
#                     "value": [
#                         91.11,
#                         29.97,
#                         24
#                     ],
#                     "name": "\u62c9\u8428"
#                 },
#                 {
#                     "value": [
#                         112.02,
#                         22.93,
#                         24
#                     ],
#                     "name": "\u4e91\u6d6e"
#                 },
#                 {
#                     "value": [
#                         116.1,
#                         24.55,
#                         25
#                     ],
#                     "name": "\u6885\u5dde"
#                 },
#                 {
#                     "value": [
#                         122.05,
#                         37.2,
#                         25
#                     ],
#                     "name": "\u6587\u767b"

# %%
    from pyecharts import Map  
    districts = ['运河区', '新华区', '泊头市', '任丘市', '黄骅市', '河间市', '沧县', '青县', '东光县', '海兴县', '盐山县', '肃宁县', '南皮县', '吴桥县', '献县', '孟村回族自治县']  
    areas = [109.92, 109.47, 1006.5, 1023.0, 1544.7, 1333.0, 1104.0, 968.0, 730.0, 915.1, 796.0, 525.0, 794.0, 600.0, 1191.0, 387.0]  
    map_1 = Map("沧州市图例－各区面积", width=1200, height=600)  
    map_1.add("", districts, areas, maptype='沧州', is_visualmap=True, visual_range=[min(areas), max(areas)],  
            visual_text_color='#000', is_map_symbol_show=False, is_label_show=True)  
    map_1
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'cang1_zhou1': '/nbextensions/echarts-china-cities-js/he2_nan2_cang1_zhou1'
#         }
#     });
# </script>
#     <div id="c64b6d6cafde431f8cfd151ee18c2427" style="width:1200px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'cang1_zhou1'], function(echarts) {
#
# var myChart_c64b6d6cafde431f8cfd151ee18c2427 = echarts.init(document.getElementById('c64b6d6cafde431f8cfd151ee18c2427'), 'light', {renderer: 'canvas'});
#
# var option_c64b6d6cafde431f8cfd151ee18c2427 = {
#     "toolbox": {
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         },
#         "orient": "vertical",
#         "left": "95%",
#         "show": true,
#         "top": "center"
#     },
#     "series_id": 1405821,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "visualMap": {
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "showLabel": true,
#         "type": "continuous",
#         "max": 1544.7,
#         "calculable": true,
#         "left": "left",
#         "min": 109.47,
#         "splitNumber": 5,
#         "textStyle": {
#             "color": "#000"
#         },
#         "top": "bottom",
#         "text": [
#             "high",
#             "low"
#         ],
#         "orient": "vertical"
#     },
#     "tooltip": {
#         "triggerOn": "mousemove|click",
#         "trigger": "item",
#         "borderColor": "#333",
#         "borderWidth": 0,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "axisPointer": {
#             "type": "line"
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)"
#     },
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "show": true,
#             "top": "top",
#             "left": "center",
#             "orient": "horizontal",
#             "selectedMode": "multiple"
#         }
#     ],
#     "title": [
#         {
#             "text": "\u6ca7\u5dde\u5e02\u56fe\u4f8b\uff0d\u5404\u533a\u9762\u79ef",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "left": "auto",
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "top": "auto"
#         }
#     ],
#     "series": [
#         {
#             "data": [
#                 {
#                     "value": 109.92,
#                     "name": "\u8fd0\u6cb3\u533a"
#                 },
#                 {
#                     "value": 109.47,
#                     "name": "\u65b0\u534e\u533a"
#                 },
#                 {
#                     "value": 1006.5,
#                     "name": "\u6cca\u5934\u5e02"
#                 },
#                 {
#                     "value": 1023.0,
#                     "name": "\u4efb\u4e18\u5e02"
#                 },
#                 {
#                     "value": 1544.7,
#                     "name": "\u9ec4\u9a85\u5e02"
#                 },
#                 {
#                     "value": 1333.0,
#                     "name": "\u6cb3\u95f4\u5e02"
#                 },
#                 {
#                     "value": 1104.0,
#                     "name": "\u6ca7\u53bf"
#                 },
#                 {
#                     "value": 968.0,
#                     "name": "\u9752\u53bf"
#                 },
#                 {
#                     "value": 730.0,
#                     "name": "\u4e1c\u5149\u53bf"
#                 },
#                 {
#                     "value": 915.1,
#                     "name": "\u6d77\u5174\u53bf"
#                 },
#                 {
#                     "value": 796.0,
#                     "name": "\u76d0\u5c71\u53bf"
#                 },
#                 {
#                     "value": 525.0,
#                     "name": "\u8083\u5b81\u53bf"
#                 },
#                 {
#                     "value": 794.0,
#                     "name": "\u5357\u76ae\u53bf"
#                 },
#                 {
#                     "value": 600.0,
#                     "name": "\u5434\u6865\u53bf"
#                 },
#                 {
#                     "value": 1191.0,
#                     "name": "\u732e\u53bf"
#                 },
#                 {
#                     "value": 387.0,
#                     "name": "\u5b5f\u6751\u56de\u65cf\u81ea\u6cbb\u53bf"
#                 }
#             ],
#             "symbol": "circle",
#             "roam": true,
#             "type": "map",
#             "label": {
#                 "emphasis": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": true
#                 },
#                 "normal": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": true,
#                     "position": "top"
#                 }
#             },
#             "showLegendSymbol": false,
#             "mapType": "\u6ca7\u5dde"
#         }
#     ]
# };
# myChart_c64b6d6cafde431f8cfd151ee18c2427.setOption(option_c64b6d6cafde431f8cfd151ee18c2427);
#
#     });
# </script>

# %%
from pyecharts import Bar  
  
bar = Bar("贵州GDP柱状图", "副标题")  
city = ["贵阳市", "遵义市", "六盘水市", "安顺市", "黔东南州"]  
data1 = [40, 30, 26, 22, 15]  
data2 = [13, 43, 32, 38, 20]  
bar.add("2017年GDP", city, data1)  
bar.add("2016年GDP", city, data2, is_convert=True)  
# bar.show_config()  
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="46a608127f5f44979c7c35204a296541" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_46a608127f5f44979c7c35204a296541 = echarts.init(document.getElementById('46a608127f5f44979c7c35204a296541'), 'light', {renderer: 'canvas'});
#
# var option_46a608127f5f44979c7c35204a296541 = {
#     "series_id": 7393548,
#     "xAxis": [
#         {
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "nameLocation": "middle",
#             "show": true,
#             "type": "value",
#             "axisLabel": {
#                 "interval": "auto",
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "rotate": 0,
#                 "margin": 8
#             },
#             "splitLine": {
#                 "show": false
#             },
#             "inverse": false,
#             "nameGap": 25,
#             "boundaryGap": true
#         }
#     ],
#     "toolbox": {
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         },
#         "orient": "vertical",
#         "left": "95%",
#         "show": true,
#         "top": "center"
#     },
#     "tooltip": {
#         "triggerOn": "mousemove|click",
#         "trigger": "item",
#         "borderColor": "#333",
#         "borderWidth": 0,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "axisPointer": {
#             "type": "line"
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)"
#     },
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "legend": [
#         {
#             "data": [
#                 "2017\u5e74GDP",
#                 "2016\u5e74GDP"
#             ],
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "show": true,
#             "top": "top",
#             "left": "center",
#             "orient": "horizontal",
#             "selectedMode": "multiple"
#         }
#     ],
#     "title": [
#         {
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtext": "\u526f\u6807\u9898",
#             "top": "auto",
#             "text": "\u8d35\u5ddeGDP\u67f1\u72b6\u56fe",
#             "left": "auto",
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "nameLocation": "middle",
#             "show": true,
#             "type": "value",
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "rotate": 0,
#                 "margin": 8
#             },
#             "splitLine": {
#                 "show": true
#             },
#             "inverse": false,
#             "nameGap": 25,
#             "boundaryGap": true
#         }
#     ],
#     "series": [
#         {
#             "data": [
#                 40,
#                 30,
#                 26,
#                 22,
#                 15
#             ],
#             "seriesId": 7393548,
#             "type": "bar",
#             "label": {
#                 "emphasis": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": true
#                 },
#                 "normal": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": false,
#                     "position": "top"
#                 }
#             },
#             "barCategoryGap": "20%",
#             "name": "2017\u5e74GDP"
#         },
#         {
#             "data": [
#                 13,
#                 43,
#                 32,
#                 38,
#                 20
#             ],
#             "seriesId": 7393548,
#             "type": "bar",
#             "label": {
#                 "emphasis": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": true
#                 },
#                 "normal": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": false,
#                     "position": "top"
#                 }
#             },
#             "barCategoryGap": "20%",
#             "name": "2016\u5e74GDP"
#         }
#     ]
# };
# myChart_46a608127f5f44979c7c35204a296541.setOption(option_46a608127f5f44979c7c35204a296541);
#
#     });
# </script>
